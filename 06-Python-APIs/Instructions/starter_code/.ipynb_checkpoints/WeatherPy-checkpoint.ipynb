# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 627

# %%
#Print the list of cities
for city in cities:
    print(city)
# Out:
# toftir
# luorong
# saint-louis
# luderitz
# kapaa
# ancud
# san isidro
# sobolevo
# khandyga
# sitka
# luan
# vardo
# paamiut
# nigde
# atuona
# hua hin
# isangel
# rikitea
# saskylakh
# barrow
# gizo
# yellowknife
# punta arenas
# vilhena
# coquimbo
# rottingdean
# bengkulu
# port alfred
# naze
# ushuaia
# chuy
# mataura
# mehamn
# illoqqortoormiut
# parry sound
# taolanaro
# nikolskoye
# dengzhou
# new norfolk
# puerto ayora
# kaeo
# sorland
# hithadhoo
# vaini
# churapcha
# goderich
# myslenice
# karratha
# nongstoin
# makakilo city
# hilo
# alice springs
# aykhal
# bayshore gardens
# ilulissat
# tupik
# launceston
# lasa
# thompson
# faanui
# tromso
# mapiripan
# klaksvik
# airai
# hermanus
# saint-philippe
# morris
# conde
# marzuq
# qaanaaq
# arraial do cabo
# providencia
# bredasdorp
# darovskoy
# firozabad
# payson
# samandag
# kodiak
# kurdzhinovo
# talaya
# albany
# kopashnovo
# laguna
# hasaki
# narrabri
# eyl
# tual
# castro
# avera
# busselton
# strezhevoy
# nicoya
# khatanga
# lorengau
# jamestown
# mahebourg
# severo-kurilsk
# barentsburg
# dickinson
# stoyba
# umzimvubu
# cabedelo
# la ronge
# antofagasta
# zhigansk
# bethel
# souillac
# nanortalik
# east london
# casino
# victoria
# riyadh
# jalu
# tortoli
# lipari
# chokurdakh
# kez
# hobart
# mandal
# villa carlos paz
# norman wells
# georgetown
# great yarmouth
# alvorada
# banda aceh
# eyrarbakki
# ixtapa
# komsomolskiy
# port blair
# gamba
# krasnokholm
# vladicin han
# deniliquin
# lac du bonnet
# gimli
# trincomalee
# huarmey
# mahibadhoo
# the valley
# kruisfontein
# mangit
# maraba
# mys shmidta
# bonfim
# kismayo
# chapais
# kimbe
# pisco
# kaitangata
# shelburne
# marcona
# puerto guzman
# avarua
# upernavik
# comodoro rivadavia
# dunedin
# harper
# tura
# karaul
# nishihara
# olafsvik
# karamea
# provideniya
# cape town
# batagay-alyta
# mizdah
# ribeira grande
# attawapiskat
# buchanan
# cayenne
# razole
# new plymouth
# staryy nadym
# xichang
# mar del plata
# port lincoln
# pemangkat
# nacala
# neuquen
# vigrestad
# nome
# cabo san lucas
# ostrovnoy
# tarudant
# puerto carreno
# saint george
# butaritari
# hovd
# mercedes
# la libertad
# longyearbyen
# waipawa
# kargopol
# santa cruz
# torbay
# santa fe
# champerico
# soyo
# waingapu
# solnechnyy
# carnarvon
# bambous virieux
# xai-xai
# salta
# tuktoyaktuk
# morgan city
# teknaf
# katangli
# athabasca
# sucua
# tilichiki
# maldonado
# omboue
# tulsipur
# otradinskiy
# belushya guba
# lata
# tiksi
# talnakh
# palabuhanratu
# ambilobe
# vanderhoof
# tartagal
# havelock
# nouadhibou
# bougouni
# kitgum
# ponta do sol
# vallenar
# ugoofaaru
# clyde river
# esperance
# kuruman
# cidreira
# fairbanks
# san quintin
# bluff
# san cristobal
# kavieng
# tasiilaq
# asau
# grand river south east
# zhigalovo
# pestravka
# skelleftea
# aqtobe
# russell
# kinkala
# olinda
# porto novo
# hay river
# bardiyah
# orlik
# presidencia roque saenz pena
# steinbach
# emirdag
# kiruna
# pacific grove
# luang prabang
# alta floresta
# fortuna
# vaitupu
# sao filipe
# manyana
# koslan
# tuatapere
# te anau
# adrar
# safaga
# nyurba
# roebourne
# zhangye
# beringovskiy
# praia da vitoria
# leningradskiy
# kavaratti
# woodward
# port elizabeth
# labuhan
# emerald
# salinas
# kohlu
# amderma
# osypenko
# xining
# santa cruz del sur
# rosario
# los llanos de aridane
# lebu
# ambodifototra
# barmer
# bathsheba
# dingle
# kemin
# salalah
# antsohihy
# kotdwara
# mosquera
# turbat
# yerbogachen
# bargal
# abrego
# niesky
# umba
# narasannapeta
# sentyabrskiy
# palmer
# saint-augustin
# nisia floresta
# petropavlovsk-kamchatskiy
# balimo
# dikson
# bilibino
# copiapo
# saint-francois
# kiama
# obo
# aklavik
# kudahuvadhoo
# sisimiut
# pitimbu
# leh
# kloulklubed
# swan hill
# louisbourg
# jabiru
# mpika
# namibe
# abu dhabi
# grand gaube
# ende
# erzurum
# lavrentiya
# egvekinot
# priiskovyy
# chute-aux-outardes
# boyabat
# benguela
# kachiry
# havoysund
# betare oya
# peniche
# malwan
# bonthe
# san policarpo
# aviles
# kununurra
# vila franca do campo
# palaikastron
# labuan
# mamakan
# aksha
# tres palos
# ottobrunn
# baft
# lompoc
# naryan-mar
# borogontsy
# kokorevka
# warri
# pevek
# baykit
# manaure
# mana
# paso de carrasco
# saint anthony
# houma
# tremedal
# dubenskiy
# geraldton
# nantucket
# vorukh
# kajaani
# phnum penh
# tsihombe
# agua branca
# ketchikan
# xuddur
# mangrol
# pyaozerskiy
# coron
# liwale
# kalmunai
# taloqan
# ranong
# sangamner
# akdepe
# bolnisi
# lagoa
# saldanha
# seybaplaya
# penzance
# alpena
# paragominas
# hamilton
# port hardy
# nemuro
# ahipara
# praya
# ulaangom
# san lazaro
# vao
# khonuu
# quelimane
# vostok
# osakarovka
# taltal
# narsaq
# taquaritinga do norte
# cherskiy
# tawang
# tadine
# bandundu
# prince george
# kahta
# mamallapuram
# bridlington
# oranjemund
# okhotsk
# galveston
# bud
# grand-lahou
# yerofey pavlovich
# russkaya polyana
# bogande
# tecoanapa
# kemijarvi
# artigas
# magsaysay
# hambantota
# quetzaltenango
# ayan
# botwood
# trinidad
# wagar
# linxi
# waddan
# vestmannaeyjar
# trairi
# thinadhoo
# taraz
# alofi
# san patricio
# nhulunbuy
# vanavara
# nayoro
# ndola
# ruatoria
# suraabad
# zhuhai
# bell ville
# carauari
# tomatlan
# aksarka
# agapovka
# chimoio
# farmington
# necochea
# tahoua
# esmeralda
# youkounkoun
# portland
# aswan
# maniitsoq
# rawson
# kinna
# zenzeli
# bay roberts
# creel
# flinders
# birin
# tumannyy
# mgandu
# ngukurr
# rungata
# sens
# sakakah
# gasa
# constitucion
# ola
# north bend
# zempoala
# filadelfia
# natal
# cleethorpes
# evensk
# segou
# kahului
# murakami
# guiratinga
# alugan
# tambun
# barcelos
# mweka
# mount gambier
# lensk
# codrington
# mount isa
# beloha
# rapid valley
# palembang
# muros
# ravar
# old bridge
# tsumeb
# cazaje
# sierra vista
# mokhsogollokh
# turukhansk
# yarada
# kamenskoye
# katsuura
# phuket
# kieta
# matara
# inhambane
# tunduru
# nelson bay
# mildura
# baringo
# luganville
# salvador
# grindavik
# darnah
# saleaula
# melchor de mencos
# young
# luanda
# griffith
# dawei
# machilipatnam
# puerto leguizamo
# manturovo
# andenes
# jever
# itapora
# maceio
# briceno
# makaha
# sembe
# fallon
# serowe
# timra
# bajo baudo
# benghazi
# puerto quijarro
# maragogi
# san mateo ixtatan
# port hedland
# podlesnyy
# adeje
# chamba
# umm lajj
# knysna
# veraval
# iqaluit
# mitsamiouli
# touros
# tynda
# taoudenni
# boma
# alexander city
# shizuishan
# mitu
# guerrero negro
# coruripe
# kabalo
# yangambi
# belfast
# savonlinna
# namatanai
# sinnamary
# cagayan de tawi-tawi
# chicama
# wuchang
# tautira
# saint-pierre
# ostrogozhsk
# warrington
# caravelas
# bereda
# nizhneyansk
# kaoma
# kathmandu
# dire dawa
# torrox
# anadyr
# svetlogorsk
# axim
# ormara
# arrecife
# sainte-marie
# nabire
# shima
# kroya
# samokov
# bongandanga
# bandarbeyla
# semey
# sesheke
# comarapa
# itarema
# ust-tsilma
# kenai
# sangar
# carutapera
# lumphat
# tucurui
# igarka
# termoli
# yar-sale
# meadow lake
# dryden
# ixcatepec
# berlevag
# kachug
# vermillion
# sena madureira
# ust-kamchatsk
# mutsamudu
# catanzaro
# pudozh
# japura
# vila velha
# surt
# seoul
# acarau

# %%
# Weathermap URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# %%
#Print the cities 
cities_url=[]
count = 0
set = 1
for city in cities :
    query_url = url+'q='+city+'&appid='+api_key+'&units=imperial'
    cities_url.append(query_url)
    if count <50:
        print(f'Processing Record {count} of Set{set} | {city}')
        count = count+1
    else:
        count = 0
        set = set +1
cities_url[0]
# Out:
# Processing Record 0 of Set1 | toftir
# Processing Record 1 of Set1 | luorong
# Processing Record 2 of Set1 | saint-louis
# Processing Record 3 of Set1 | luderitz
# Processing Record 4 of Set1 | kapaa
# Processing Record 5 of Set1 | ancud
# Processing Record 6 of Set1 | san isidro
# Processing Record 7 of Set1 | sobolevo
# Processing Record 8 of Set1 | khandyga
# Processing Record 9 of Set1 | sitka
# Processing Record 10 of Set1 | luan
# Processing Record 11 of Set1 | vardo
# Processing Record 12 of Set1 | paamiut
# Processing Record 13 of Set1 | nigde
# Processing Record 14 of Set1 | atuona
# Processing Record 15 of Set1 | hua hin
# Processing Record 16 of Set1 | isangel
# Processing Record 17 of Set1 | rikitea
# Processing Record 18 of Set1 | saskylakh
# Processing Record 19 of Set1 | barrow
# Processing Record 20 of Set1 | gizo
# Processing Record 21 of Set1 | yellowknife
# Processing Record 22 of Set1 | punta arenas
# Processing Record 23 of Set1 | vilhena
# Processing Record 24 of Set1 | coquimbo
# Processing Record 25 of Set1 | rottingdean
# Processing Record 26 of Set1 | bengkulu
# Processing Record 27 of Set1 | port alfred
# Processing Record 28 of Set1 | naze
# Processing Record 29 of Set1 | ushuaia
# Processing Record 30 of Set1 | chuy
# Processing Record 31 of Set1 | mataura
# Processing Record 32 of Set1 | mehamn
# Processing Record 33 of Set1 | illoqqortoormiut
# Processing Record 34 of Set1 | parry sound
# Processing Record 35 of Set1 | taolanaro
# Processing Record 36 of Set1 | nikolskoye
# Processing Record 37 of Set1 | dengzhou
# Processing Record 38 of Set1 | new norfolk
# Processing Record 39 of Set1 | puerto ayora
# Processing Record 40 of Set1 | kaeo
# Processing Record 41 of Set1 | sorland
# Processing Record 42 of Set1 | hithadhoo
# Processing Record 43 of Set1 | vaini
# Processing Record 44 of Set1 | churapcha
# Processing Record 45 of Set1 | goderich
# Processing Record 46 of Set1 | myslenice
# Processing Record 47 of Set1 | karratha
# Processing Record 48 of Set1 | nongstoin
# Processing Record 49 of Set1 | makakilo city
# Processing Record 0 of Set2 | alice springs
# Processing Record 1 of Set2 | aykhal
# Processing Record 2 of Set2 | bayshore gardens
# Processing Record 3 of Set2 | ilulissat
# Processing Record 4 of Set2 | tupik
# Processing Record 5 of Set2 | launceston
# Processing Record 6 of Set2 | lasa
# Processing Record 7 of Set2 | thompson
# Processing Record 8 of Set2 | faanui
# Processing Record 9 of Set2 | tromso
# Processing Record 10 of Set2 | mapiripan
# Processing Record 11 of Set2 | klaksvik
# Processing Record 12 of Set2 | airai
# Processing Record 13 of Set2 | hermanus
# Processing Record 14 of Set2 | saint-philippe
# Processing Record 15 of Set2 | morris
# Processing Record 16 of Set2 | conde
# Processing Record 17 of Set2 | marzuq
# Processing Record 18 of Set2 | qaanaaq
# Processing Record 19 of Set2 | arraial do cabo
# Processing Record 20 of Set2 | providencia
# Processing Record 21 of Set2 | bredasdorp
# Processing Record 22 of Set2 | darovskoy
# Processing Record 23 of Set2 | firozabad
# Processing Record 24 of Set2 | payson
# Processing Record 25 of Set2 | samandag
# Processing Record 26 of Set2 | kodiak
# Processing Record 27 of Set2 | kurdzhinovo
# Processing Record 28 of Set2 | talaya
# Processing Record 29 of Set2 | albany
# Processing Record 30 of Set2 | kopashnovo
# Processing Record 31 of Set2 | laguna
# Processing Record 32 of Set2 | hasaki
# Processing Record 33 of Set2 | narrabri
# Processing Record 34 of Set2 | eyl
# Processing Record 35 of Set2 | tual
# Processing Record 36 of Set2 | castro
# Processing Record 37 of Set2 | avera
# Processing Record 38 of Set2 | busselton
# Processing Record 39 of Set2 | strezhevoy
# Processing Record 40 of Set2 | nicoya
# Processing Record 41 of Set2 | khatanga
# Processing Record 42 of Set2 | lorengau
# Processing Record 43 of Set2 | jamestown
# Processing Record 44 of Set2 | mahebourg
# Processing Record 45 of Set2 | severo-kurilsk
# Processing Record 46 of Set2 | barentsburg
# Processing Record 47 of Set2 | dickinson
# Processing Record 48 of Set2 | stoyba
# Processing Record 49 of Set2 | umzimvubu
# Processing Record 0 of Set3 | la ronge
# Processing Record 1 of Set3 | antofagasta
# Processing Record 2 of Set3 | zhigansk
# Processing Record 3 of Set3 | bethel
# Processing Record 4 of Set3 | souillac
# Processing Record 5 of Set3 | nanortalik
# Processing Record 6 of Set3 | east london
# Processing Record 7 of Set3 | casino
# Processing Record 8 of Set3 | victoria
# Processing Record 9 of Set3 | riyadh
# Processing Record 10 of Set3 | jalu
# Processing Record 11 of Set3 | tortoli
# Processing Record 12 of Set3 | lipari
# Processing Record 13 of Set3 | chokurdakh
# Processing Record 14 of Set3 | kez
# Processing Record 15 of Set3 | hobart
# Processing Record 16 of Set3 | mandal
# Processing Record 17 of Set3 | villa carlos paz
# Processing Record 18 of Set3 | norman wells
# Processing Record 19 of Set3 | georgetown
# Processing Record 20 of Set3 | great yarmouth
# Processing Record 21 of Set3 | alvorada
# Processing Record 22 of Set3 | banda aceh
# Processing Record 23 of Set3 | eyrarbakki
# Processing Record 24 of Set3 | ixtapa
# Processing Record 25 of Set3 | komsomolskiy
# Processing Record 26 of Set3 | port blair
# Processing Record 27 of Set3 | gamba
# Processing Record 28 of Set3 | krasnokholm
# Processing Record 29 of Set3 | vladicin han
# Processing Record 30 of Set3 | deniliquin
# Processing Record 31 of Set3 | lac du bonnet
# Processing Record 32 of Set3 | gimli
# Processing Record 33 of Set3 | trincomalee
# Processing Record 34 of Set3 | huarmey
# Processing Record 35 of Set3 | mahibadhoo
# Processing Record 36 of Set3 | the valley
# Processing Record 37 of Set3 | kruisfontein
# Processing Record 38 of Set3 | mangit
# Processing Record 39 of Set3 | maraba
# Processing Record 40 of Set3 | mys shmidta
# Processing Record 41 of Set3 | bonfim
# Processing Record 42 of Set3 | kismayo
# Processing Record 43 of Set3 | chapais
# Processing Record 44 of Set3 | kimbe
# Processing Record 45 of Set3 | pisco
# Processing Record 46 of Set3 | kaitangata
# Processing Record 47 of Set3 | shelburne
# Processing Record 48 of Set3 | marcona
# Processing Record 49 of Set3 | puerto guzman
# Processing Record 0 of Set4 | upernavik
# Processing Record 1 of Set4 | comodoro rivadavia
# Processing Record 2 of Set4 | dunedin
# Processing Record 3 of Set4 | harper
# Processing Record 4 of Set4 | tura
# Processing Record 5 of Set4 | karaul
# Processing Record 6 of Set4 | nishihara
# Processing Record 7 of Set4 | olafsvik
# Processing Record 8 of Set4 | karamea
# Processing Record 9 of Set4 | provideniya
# Processing Record 10 of Set4 | cape town
# Processing Record 11 of Set4 | batagay-alyta
# Processing Record 12 of Set4 | mizdah
# Processing Record 13 of Set4 | ribeira grande
# Processing Record 14 of Set4 | attawapiskat
# Processing Record 15 of Set4 | buchanan
# Processing Record 16 of Set4 | cayenne
# Processing Record 17 of Set4 | razole
# Processing Record 18 of Set4 | new plymouth
# Processing Record 19 of Set4 | staryy nadym
# Processing Record 20 of Set4 | xichang
# Processing Record 21 of Set4 | mar del plata
# Processing Record 22 of Set4 | port lincoln
# Processing Record 23 of Set4 | pemangkat
# Processing Record 24 of Set4 | nacala
# Processing Record 25 of Set4 | neuquen
# Processing Record 26 of Set4 | vigrestad
# Processing Record 27 of Set4 | nome
# Processing Record 28 of Set4 | cabo san lucas
# Processing Record 29 of Set4 | ostrovnoy
# Processing Record 30 of Set4 | tarudant
# Processing Record 31 of Set4 | puerto carreno
# Processing Record 32 of Set4 | saint george
# Processing Record 33 of Set4 | butaritari
# Processing Record 34 of Set4 | hovd
# Processing Record 35 of Set4 | mercedes
# Processing Record 36 of Set4 | la libertad
# Processing Record 37 of Set4 | longyearbyen
# Processing Record 38 of Set4 | waipawa
# Processing Record 39 of Set4 | kargopol
# Processing Record 40 of Set4 | santa cruz
# Processing Record 41 of Set4 | torbay
# Processing Record 42 of Set4 | santa fe
# Processing Record 43 of Set4 | champerico
# Processing Record 44 of Set4 | soyo
# Processing Record 45 of Set4 | waingapu
# Processing Record 46 of Set4 | solnechnyy
# Processing Record 47 of Set4 | carnarvon
# Processing Record 48 of Set4 | bambous virieux
# Processing Record 49 of Set4 | xai-xai
# Processing Record 0 of Set5 | tuktoyaktuk
# Processing Record 1 of Set5 | morgan city
# Processing Record 2 of Set5 | teknaf
# Processing Record 3 of Set5 | katangli
# Processing Record 4 of Set5 | athabasca
# Processing Record 5 of Set5 | sucua
# Processing Record 6 of Set5 | tilichiki
# Processing Record 7 of Set5 | maldonado
# Processing Record 8 of Set5 | omboue
# Processing Record 9 of Set5 | tulsipur
# Processing Record 10 of Set5 | otradinskiy
# Processing Record 11 of Set5 | belushya guba
# Processing Record 12 of Set5 | lata
# Processing Record 13 of Set5 | tiksi
# Processing Record 14 of Set5 | talnakh
# Processing Record 15 of Set5 | palabuhanratu
# Processing Record 16 of Set5 | ambilobe
# Processing Record 17 of Set5 | vanderhoof
# Processing Record 18 of Set5 | tartagal
# Processing Record 19 of Set5 | havelock
# Processing Record 20 of Set5 | nouadhibou
# Processing Record 21 of Set5 | bougouni
# Processing Record 22 of Set5 | kitgum
# Processing Record 23 of Set5 | ponta do sol
# Processing Record 24 of Set5 | vallenar
# Processing Record 25 of Set5 | ugoofaaru
# Processing Record 26 of Set5 | clyde river
# Processing Record 27 of Set5 | esperance
# Processing Record 28 of Set5 | kuruman
# Processing Record 29 of Set5 | cidreira
# Processing Record 30 of Set5 | fairbanks
# Processing Record 31 of Set5 | san quintin
# Processing Record 32 of Set5 | bluff
# Processing Record 33 of Set5 | san cristobal
# Processing Record 34 of Set5 | kavieng
# Processing Record 35 of Set5 | tasiilaq
# Processing Record 36 of Set5 | asau
# Processing Record 37 of Set5 | grand river south east
# Processing Record 38 of Set5 | zhigalovo
# Processing Record 39 of Set5 | pestravka
# Processing Record 40 of Set5 | skelleftea
# Processing Record 41 of Set5 | aqtobe
# Processing Record 42 of Set5 | russell
# Processing Record 43 of Set5 | kinkala
# Processing Record 44 of Set5 | olinda
# Processing Record 45 of Set5 | porto novo
# Processing Record 46 of Set5 | hay river
# Processing Record 47 of Set5 | bardiyah
# Processing Record 48 of Set5 | orlik
# Processing Record 49 of Set5 | presidencia roque saenz pena
# Processing Record 0 of Set6 | emirdag
# Processing Record 1 of Set6 | kiruna
# Processing Record 2 of Set6 | pacific grove
# Processing Record 3 of Set6 | luang prabang
# Processing Record 4 of Set6 | alta floresta
# Processing Record 5 of Set6 | fortuna
# Processing Record 6 of Set6 | vaitupu
# Processing Record 7 of Set6 | sao filipe
# Processing Record 8 of Set6 | manyana
# Processing Record 9 of Set6 | koslan
# Processing Record 10 of Set6 | tuatapere
# Processing Record 11 of Set6 | te anau
# Processing Record 12 of Set6 | adrar
# Processing Record 13 of Set6 | safaga
# Processing Record 14 of Set6 | nyurba
# Processing Record 15 of Set6 | roebourne
# Processing Record 16 of Set6 | zhangye
# Processing Record 17 of Set6 | beringovskiy
# Processing Record 18 of Set6 | praia da vitoria
# Processing Record 19 of Set6 | leningradskiy
# Processing Record 20 of Set6 | kavaratti
# Processing Record 21 of Set6 | woodward
# Processing Record 22 of Set6 | port elizabeth
# Processing Record 23 of Set6 | labuhan
# Processing Record 24 of Set6 | emerald
# Processing Record 25 of Set6 | salinas
# Processing Record 26 of Set6 | kohlu
# Processing Record 27 of Set6 | amderma
# Processing Record 28 of Set6 | osypenko
# Processing Record 29 of Set6 | xining
# Processing Record 30 of Set6 | santa cruz del sur
# Processing Record 31 of Set6 | rosario
# Processing Record 32 of Set6 | los llanos de aridane
# Processing Record 33 of Set6 | lebu
# Processing Record 34 of Set6 | ambodifototra
# Processing Record 35 of Set6 | barmer
# Processing Record 36 of Set6 | bathsheba
# Processing Record 37 of Set6 | dingle
# Processing Record 38 of Set6 | kemin
# Processing Record 39 of Set6 | salalah
# Processing Record 40 of Set6 | antsohihy
# Processing Record 41 of Set6 | kotdwara
# Processing Record 42 of Set6 | mosquera
# Processing Record 43 of Set6 | turbat
# Processing Record 44 of Set6 | yerbogachen
# Processing Record 45 of Set6 | bargal
# Processing Record 46 of Set6 | abrego
# Processing Record 47 of Set6 | niesky
# Processing Record 48 of Set6 | umba
# Processing Record 49 of Set6 | narasannapeta
# Processing Record 0 of Set7 | palmer
# Processing Record 1 of Set7 | saint-augustin
# Processing Record 2 of Set7 | nisia floresta
# Processing Record 3 of Set7 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set7 | balimo
# Processing Record 5 of Set7 | dikson
# Processing Record 6 of Set7 | bilibino
# Processing Record 7 of Set7 | copiapo
# Processing Record 8 of Set7 | saint-francois
# Processing Record 9 of Set7 | kiama
# Processing Record 10 of Set7 | obo
# Processing Record 11 of Set7 | aklavik
# Processing Record 12 of Set7 | kudahuvadhoo
# Processing Record 13 of Set7 | sisimiut
# Processing Record 14 of Set7 | pitimbu
# Processing Record 15 of Set7 | leh
# Processing Record 16 of Set7 | kloulklubed
# Processing Record 17 of Set7 | swan hill
# Processing Record 18 of Set7 | louisbourg
# Processing Record 19 of Set7 | jabiru
# Processing Record 20 of Set7 | mpika
# Processing Record 21 of Set7 | namibe
# Processing Record 22 of Set7 | abu dhabi
# Processing Record 23 of Set7 | grand gaube
# Processing Record 24 of Set7 | ende
# Processing Record 25 of Set7 | erzurum
# Processing Record 26 of Set7 | lavrentiya
# Processing Record 27 of Set7 | egvekinot
# Processing Record 28 of Set7 | priiskovyy
# Processing Record 29 of Set7 | chute-aux-outardes
# Processing Record 30 of Set7 | boyabat
# Processing Record 31 of Set7 | benguela
# Processing Record 32 of Set7 | kachiry
# Processing Record 33 of Set7 | havoysund
# Processing Record 34 of Set7 | betare oya
# Processing Record 35 of Set7 | peniche
# Processing Record 36 of Set7 | malwan
# Processing Record 37 of Set7 | bonthe
# Processing Record 38 of Set7 | san policarpo
# Processing Record 39 of Set7 | aviles
# Processing Record 40 of Set7 | kununurra
# Processing Record 41 of Set7 | vila franca do campo
# Processing Record 42 of Set7 | palaikastron
# Processing Record 43 of Set7 | labuan
# Processing Record 44 of Set7 | mamakan
# Processing Record 45 of Set7 | aksha
# Processing Record 46 of Set7 | tres palos
# Processing Record 47 of Set7 | ottobrunn
# Processing Record 48 of Set7 | baft
# Processing Record 49 of Set7 | lompoc
# Processing Record 0 of Set8 | borogontsy
# Processing Record 1 of Set8 | kokorevka
# Processing Record 2 of Set8 | warri
# Processing Record 3 of Set8 | pevek
# Processing Record 4 of Set8 | baykit
# Processing Record 5 of Set8 | manaure
# Processing Record 6 of Set8 | mana
# Processing Record 7 of Set8 | paso de carrasco
# Processing Record 8 of Set8 | saint anthony
# Processing Record 9 of Set8 | houma
# Processing Record 10 of Set8 | tremedal
# Processing Record 11 of Set8 | dubenskiy
# Processing Record 12 of Set8 | geraldton
# Processing Record 13 of Set8 | nantucket
# Processing Record 14 of Set8 | vorukh
# Processing Record 15 of Set8 | kajaani
# Processing Record 16 of Set8 | phnum penh
# Processing Record 17 of Set8 | tsihombe
# Processing Record 18 of Set8 | agua branca
# Processing Record 19 of Set8 | ketchikan
# Processing Record 20 of Set8 | xuddur
# Processing Record 21 of Set8 | mangrol
# Processing Record 22 of Set8 | pyaozerskiy
# Processing Record 23 of Set8 | coron
# Processing Record 24 of Set8 | liwale
# Processing Record 25 of Set8 | kalmunai
# Processing Record 26 of Set8 | taloqan
# Processing Record 27 of Set8 | ranong
# Processing Record 28 of Set8 | sangamner
# Processing Record 29 of Set8 | akdepe
# Processing Record 30 of Set8 | bolnisi
# Processing Record 31 of Set8 | lagoa
# Processing Record 32 of Set8 | saldanha
# Processing Record 33 of Set8 | seybaplaya
# Processing Record 34 of Set8 | penzance
# Processing Record 35 of Set8 | alpena
# Processing Record 36 of Set8 | paragominas
# Processing Record 37 of Set8 | hamilton
# Processing Record 38 of Set8 | port hardy
# Processing Record 39 of Set8 | nemuro
# Processing Record 40 of Set8 | ahipara
# Processing Record 41 of Set8 | praya
# Processing Record 42 of Set8 | ulaangom
# Processing Record 43 of Set8 | san lazaro
# Processing Record 44 of Set8 | vao
# Processing Record 45 of Set8 | khonuu
# Processing Record 46 of Set8 | quelimane
# Processing Record 47 of Set8 | vostok
# Processing Record 48 of Set8 | osakarovka
# Processing Record 49 of Set8 | taltal
# Processing Record 0 of Set9 | taquaritinga do norte
# Processing Record 1 of Set9 | cherskiy
# Processing Record 2 of Set9 | tawang
# Processing Record 3 of Set9 | tadine
# Processing Record 4 of Set9 | bandundu
# Processing Record 5 of Set9 | prince george
# Processing Record 6 of Set9 | kahta
# Processing Record 7 of Set9 | mamallapuram
# Processing Record 8 of Set9 | bridlington
# Processing Record 9 of Set9 | oranjemund
# Processing Record 10 of Set9 | okhotsk
# Processing Record 11 of Set9 | galveston
# Processing Record 12 of Set9 | bud
# Processing Record 13 of Set9 | grand-lahou
# Processing Record 14 of Set9 | yerofey pavlovich
# Processing Record 15 of Set9 | russkaya polyana
# Processing Record 16 of Set9 | bogande
# Processing Record 17 of Set9 | tecoanapa
# Processing Record 18 of Set9 | kemijarvi
# Processing Record 19 of Set9 | artigas
# Processing Record 20 of Set9 | magsaysay
# Processing Record 21 of Set9 | hambantota
# Processing Record 22 of Set9 | quetzaltenango
# Processing Record 23 of Set9 | ayan
# Processing Record 24 of Set9 | botwood
# Processing Record 25 of Set9 | trinidad
# Processing Record 26 of Set9 | wagar
# Processing Record 27 of Set9 | linxi
# Processing Record 28 of Set9 | waddan
# Processing Record 29 of Set9 | vestmannaeyjar
# Processing Record 30 of Set9 | trairi
# Processing Record 31 of Set9 | thinadhoo
# Processing Record 32 of Set9 | taraz
# Processing Record 33 of Set9 | alofi
# Processing Record 34 of Set9 | san patricio
# Processing Record 35 of Set9 | nhulunbuy
# Processing Record 36 of Set9 | vanavara
# Processing Record 37 of Set9 | nayoro
# Processing Record 38 of Set9 | ndola
# Processing Record 39 of Set9 | ruatoria
# Processing Record 40 of Set9 | suraabad
# Processing Record 41 of Set9 | zhuhai
# Processing Record 42 of Set9 | bell ville
# Processing Record 43 of Set9 | carauari
# Processing Record 44 of Set9 | tomatlan
# Processing Record 45 of Set9 | aksarka
# Processing Record 46 of Set9 | agapovka
# Processing Record 47 of Set9 | chimoio
# Processing Record 48 of Set9 | farmington
# Processing Record 49 of Set9 | necochea
# Processing Record 0 of Set10 | esmeralda
# Processing Record 1 of Set10 | youkounkoun
# Processing Record 2 of Set10 | portland
# Processing Record 3 of Set10 | aswan
# Processing Record 4 of Set10 | maniitsoq
# Processing Record 5 of Set10 | rawson
# Processing Record 6 of Set10 | kinna
# Processing Record 7 of Set10 | zenzeli
# Processing Record 8 of Set10 | bay roberts
# Processing Record 9 of Set10 | creel
# Processing Record 10 of Set10 | flinders
# Processing Record 11 of Set10 | birin
# Processing Record 12 of Set10 | tumannyy
# Processing Record 13 of Set10 | mgandu
# Processing Record 14 of Set10 | ngukurr
# Processing Record 15 of Set10 | rungata
# Processing Record 16 of Set10 | sens
# Processing Record 17 of Set10 | sakakah
# Processing Record 18 of Set10 | gasa
# Processing Record 19 of Set10 | constitucion
# Processing Record 20 of Set10 | ola
# Processing Record 21 of Set10 | north bend
# Processing Record 22 of Set10 | zempoala
# Processing Record 23 of Set10 | filadelfia
# Processing Record 24 of Set10 | natal
# Processing Record 25 of Set10 | cleethorpes
# Processing Record 26 of Set10 | evensk
# Processing Record 27 of Set10 | segou
# Processing Record 28 of Set10 | kahului
# Processing Record 29 of Set10 | murakami
# Processing Record 30 of Set10 | guiratinga
# Processing Record 31 of Set10 | alugan
# Processing Record 32 of Set10 | tambun
# Processing Record 33 of Set10 | barcelos
# Processing Record 34 of Set10 | mweka
# Processing Record 35 of Set10 | mount gambier
# Processing Record 36 of Set10 | lensk
# Processing Record 37 of Set10 | codrington
# Processing Record 38 of Set10 | mount isa
# Processing Record 39 of Set10 | beloha
# Processing Record 40 of Set10 | rapid valley
# Processing Record 41 of Set10 | palembang
# Processing Record 42 of Set10 | muros
# Processing Record 43 of Set10 | ravar
# Processing Record 44 of Set10 | old bridge
# Processing Record 45 of Set10 | tsumeb
# Processing Record 46 of Set10 | cazaje
# Processing Record 47 of Set10 | sierra vista
# Processing Record 48 of Set10 | mokhsogollokh
# Processing Record 49 of Set10 | turukhansk
# Processing Record 0 of Set11 | kamenskoye
# Processing Record 1 of Set11 | katsuura
# Processing Record 2 of Set11 | phuket
# Processing Record 3 of Set11 | kieta
# Processing Record 4 of Set11 | matara
# Processing Record 5 of Set11 | inhambane
# Processing Record 6 of Set11 | tunduru
# Processing Record 7 of Set11 | nelson bay
# Processing Record 8 of Set11 | mildura
# Processing Record 9 of Set11 | baringo
# Processing Record 10 of Set11 | luganville
# Processing Record 11 of Set11 | salvador
# Processing Record 12 of Set11 | grindavik
# Processing Record 13 of Set11 | darnah
# Processing Record 14 of Set11 | saleaula
# Processing Record 15 of Set11 | melchor de mencos
# Processing Record 16 of Set11 | young
# Processing Record 17 of Set11 | luanda
# Processing Record 18 of Set11 | griffith
# Processing Record 19 of Set11 | dawei
# Processing Record 20 of Set11 | machilipatnam
# Processing Record 21 of Set11 | puerto leguizamo
# Processing Record 22 of Set11 | manturovo
# Processing Record 23 of Set11 | andenes
# Processing Record 24 of Set11 | jever
# Processing Record 25 of Set11 | itapora
# Processing Record 26 of Set11 | maceio
# Processing Record 27 of Set11 | briceno
# Processing Record 28 of Set11 | makaha
# Processing Record 29 of Set11 | sembe
# Processing Record 30 of Set11 | fallon
# Processing Record 31 of Set11 | serowe
# Processing Record 32 of Set11 | timra
# Processing Record 33 of Set11 | bajo baudo
# Processing Record 34 of Set11 | benghazi
# Processing Record 35 of Set11 | puerto quijarro
# Processing Record 36 of Set11 | maragogi
# Processing Record 37 of Set11 | san mateo ixtatan
# Processing Record 38 of Set11 | port hedland
# Processing Record 39 of Set11 | podlesnyy
# Processing Record 40 of Set11 | adeje
# Processing Record 41 of Set11 | chamba
# Processing Record 42 of Set11 | umm lajj
# Processing Record 43 of Set11 | knysna
# Processing Record 44 of Set11 | veraval
# Processing Record 45 of Set11 | iqaluit
# Processing Record 46 of Set11 | mitsamiouli
# Processing Record 47 of Set11 | touros
# Processing Record 48 of Set11 | tynda
# Processing Record 49 of Set11 | taoudenni
# Processing Record 0 of Set12 | alexander city
# Processing Record 1 of Set12 | shizuishan
# Processing Record 2 of Set12 | mitu
# Processing Record 3 of Set12 | guerrero negro
# Processing Record 4 of Set12 | coruripe
# Processing Record 5 of Set12 | kabalo
# Processing Record 6 of Set12 | yangambi
# Processing Record 7 of Set12 | belfast
# Processing Record 8 of Set12 | savonlinna
# Processing Record 9 of Set12 | namatanai
# Processing Record 10 of Set12 | sinnamary
# Processing Record 11 of Set12 | cagayan de tawi-tawi
# Processing Record 12 of Set12 | chicama
# Processing Record 13 of Set12 | wuchang
# Processing Record 14 of Set12 | tautira
# Processing Record 15 of Set12 | saint-pierre
# Processing Record 16 of Set12 | ostrogozhsk
# Processing Record 17 of Set12 | warrington
# Processing Record 18 of Set12 | caravelas
# Processing Record 19 of Set12 | bereda
# Processing Record 20 of Set12 | nizhneyansk
# Processing Record 21 of Set12 | kaoma
# Processing Record 22 of Set12 | kathmandu
# Processing Record 23 of Set12 | dire dawa
# Processing Record 24 of Set12 | torrox
# Processing Record 25 of Set12 | anadyr
# Processing Record 26 of Set12 | svetlogorsk
# Processing Record 27 of Set12 | axim
# Processing Record 28 of Set12 | ormara
# Processing Record 29 of Set12 | arrecife
# Processing Record 30 of Set12 | sainte-marie
# Processing Record 31 of Set12 | nabire
# Processing Record 32 of Set12 | shima
# Processing Record 33 of Set12 | kroya
# Processing Record 34 of Set12 | samokov
# Processing Record 35 of Set12 | bongandanga
# Processing Record 36 of Set12 | bandarbeyla
# Processing Record 37 of Set12 | semey
# Processing Record 38 of Set12 | sesheke
# Processing Record 39 of Set12 | comarapa
# Processing Record 40 of Set12 | itarema
# Processing Record 41 of Set12 | ust-tsilma
# Processing Record 42 of Set12 | kenai
# Processing Record 43 of Set12 | sangar
# Processing Record 44 of Set12 | carutapera
# Processing Record 45 of Set12 | lumphat
# Processing Record 46 of Set12 | tucurui
# Processing Record 47 of Set12 | igarka
# Processing Record 48 of Set12 | termoli
# Processing Record 49 of Set12 | yar-sale
# Processing Record 0 of Set13 | dryden
# Processing Record 1 of Set13 | ixcatepec
# Processing Record 2 of Set13 | berlevag
# Processing Record 3 of Set13 | kachug
# Processing Record 4 of Set13 | vermillion
# Processing Record 5 of Set13 | sena madureira
# Processing Record 6 of Set13 | ust-kamchatsk
# Processing Record 7 of Set13 | mutsamudu
# Processing Record 8 of Set13 | catanzaro
# Processing Record 9 of Set13 | pudozh
# Processing Record 10 of Set13 | japura
# Processing Record 11 of Set13 | vila velha
# Processing Record 12 of Set13 | surt
# Processing Record 13 of Set13 | seoul
# Processing Record 14 of Set13 | acarau
# 'http://api.openweathermap.org/data/2.5/weather?q=toftir&appid=8cb90c33f4742bc3d3b1c3cd3a11e2ba&units=imperial'

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create empty dataframe to append all values

df = pd. DataFrame({'city':[],
                   'temperature':[],
                   'cloudiness':[],
                   'country':[],
                   'date':[],
                   'humidity':[],
                   'longitude':[],
                   'latitude':[],
                   'temp_max':[],
                   'wind_speed':[]})
df.head()
# Out:
# Empty DataFrame
# Columns: [city, temperature, cloudiness, country, date, humidity, longitude, latitude, temp_max, wind_speed]
# Index: []

# %%
#Perform the response request for all city urls
now = datetime.now()
for city in cities :
    query_url = url+'q='+city+'&appid='+api_key+'&units=imperial'
    try:
        response = requests.get(query_url).json()
        df = df.append({'city':response['name'],
                   'temperature':response['main']['temp'],
                   'cloudiness':response['clouds']['all'],
                   'country':response['sys']['country'],
                   'date':now.strftime("%m/%d/%Y"),
                   'humidity':response['main']['humidity'],
                   'longitude':response['coord']['lon'],
                   'latitude':response['coord']['lat'],
                   'temp_max':response['main']['temp_max'],
                   'wind_speed':response['wind']['speed']},ignore_index=True)
        
    except Exception as e:
            print(f'Response for {city} not found : Error:{e}')
        
df.head()
# Out:
# Response for toftir not found : Error:'name'
# Response for bengkulu not found : Error:'name'
# Response for illoqqortoormiut not found : Error:'name'
# Response for taolanaro not found : Error:'name'
# Response for samandag not found : Error:'name'
# Response for barentsburg not found : Error:'name'
# Response for stoyba not found : Error:'name'
# Response for umzimvubu not found : Error:'name'
# Response for mys shmidta not found : Error:'name'
# Response for kismayo not found : Error:'name'
# Response for marcona not found : Error:'name'
# Response for karaul not found : Error:'name'
# Response for olafsvik not found : Error:'name'
# Response for karamea not found : Error:'name'
# Response for attawapiskat not found : Error:'name'
# Response for pemangkat not found : Error:'name'
# Response for tarudant not found : Error:'name'
# Response for otradinskiy not found : Error:'name'
# Response for belushya guba not found : Error:'name'
# Response for palabuhanratu not found : Error:'name'
# Response for asau not found : Error:'name'
# Response for grand river south east not found : Error:'name'
# Response for bardiyah not found : Error:'name'
# Response for vaitupu not found : Error:'name'
# Response for safaga not found : Error:'name'
# Response for amderma not found : Error:'name'
# Response for ambodifototra not found : Error:'name'
# Response for bargal not found : Error:'name'
# Response for sentyabrskiy not found : Error:'name'
# Response for balimo not found : Error:'name'
# Response for louisbourg not found : Error:'name'
# Response for jabiru not found : Error:'name'
# Response for malwan not found : Error:'name'
# Response for dubenskiy not found : Error:'name'
# Response for phnum penh not found : Error:'name'
# Response for tsihombe not found : Error:'name'
# Response for khonuu not found : Error:'name'
# Response for kemijarvi not found : Error:'name'
# Response for ruatoria not found : Error:'name'
# Response for tumannyy not found : Error:'name'
# Response for ngukurr not found : Error:'name'
# Response for rungata not found : Error:'name'
# Response for sakakah not found : Error:'name'
# Response for cazaje not found : Error:'name'
# Response for kamenskoye not found : Error:'name'
# Response for tunduru not found : Error:'name'
# Response for saleaula not found : Error:'name'
# Response for andenes not found : Error:'name'
# Response for sembe not found : Error:'name'
# Response for bajo baudo not found : Error:'name'
# Response for cagayan de tawi-tawi not found : Error:'name'
# Response for nizhneyansk not found : Error:'name'
# Response for arrecife not found : Error:'name'
# Response for ust-kamchatsk not found : Error:'name'
# Response for mutsamudu not found : Error:'name'
# Response for acarau not found : Error:'name'
#           city  temperature  cloudiness country        date  humidity  \
# 0      Luorong        60.82        38.0      CN  11/09/2019      67.0
# 1  Saint-Louis        73.40        49.0      SN  11/09/2019      73.0
# 2     Luderitz        60.80         0.0      NA  11/09/2019      87.0
# 3        Kapaa        80.04         1.0      US  11/09/2019      69.0
# 4        Ancud        53.60        92.0      CL  11/09/2019      87.0
#
#    longitude  latitude  temp_max  wind_speed
# 0     109.60     24.41     60.82        3.96
# 1     -16.50     16.03     73.40        4.70
# 2      15.16    -26.65     60.80        6.93
# 3    -159.32     22.08     80.60        8.05
# 4     -73.83    -41.87     53.60        5.82

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 10 columns):
# city           571 non-null object
# temperature    571 non-null float64
# cloudiness     571 non-null float64
# country        571 non-null object
# date           571 non-null object
# humidity       571 non-null float64
# longitude      571 non-null float64
# latitude       571 non-null float64
# temp_max       571 non-null float64
# wind_speed     571 non-null float64
# dtypes: float64(7), object(3)
# memory usage: 44.7+ KB

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df.to_csv(r'city_weatherdata.csv')

# %%
#Get the date into a variable from the dataset
a = df['date'][0]
df['wind_speed'] = df['wind_speed'].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 10 columns):
# city           571 non-null object
# temperature    571 non-null float64
# cloudiness     571 non-null float64
# country        571 non-null object
# date           571 non-null object
# humidity       571 non-null float64
# longitude      571 non-null float64
# latitude       571 non-null float64
# temp_max       571 non-null float64
# wind_speed     571 non-null float64
# dtypes: float64(7), object(3)
# memory usage: 44.7+ KB

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
df.plot(kind='scatter',x='latitude',y='temperature')
plt.xlabel('Latitide')
plt.ylabel('Temperature_F')
plt.title('Temperature by City Latitude on '+ a)
plt.savefig('Temperature by Latitude.png')
plt.grid()

#Inference: As latitude moves away from Equator, from 0 degrees, the temperature falls.Highest temp recorded at equator.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
df.plot(kind='scatter',x='latitude',y='humidity')
plt.xlabel('Latitide')
plt.ylabel('Humidity(%)')
plt.title('Humidity by City Latitude on '+ a)
plt.savefig('Humidity by Latitude.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
df.plot(kind='scatter',x='latitude',y='cloudiness')
plt.xlabel('Latitide')
plt.ylabel('Cloudiness(%)')
plt.title('Cloudiness by City Latitude on '+ a)
plt.savefig('Cloudiness by Latitude.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
df.plot(kind='scatter',x='latitude',y='wind_speed')
plt.xlabel('Latitide')
plt.ylabel('wind_speed')
plt.title('Wind Speed by City Latitude on '+ a)
plt.savefig('Wind Speed by Latitude.png')
